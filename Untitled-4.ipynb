# %%
import pandas as pd

# %%
cont_df = pd.read_csv("C:/Users/lravlic/PROYECTOS DATA/TRANSITO SQL/Z_CONT.csv", dtype={'NRO_OC_SAP':'str','POS_OC_SAP':'str', 'NRO_MIRO':'str'})

# %%
cont_df.head()
# Out:
#    NRO_OC_SAP POS_OC_SAP    NRO_MIRO IND_BORRADO_OC IND_BORRADO_PO  \
# 0  4300018809      00040  5106458226            NaN            NaN
# 1  4300018958      00040  5106472753            NaN            NaN
# 2  4300020185      00010  5106527617            NaN            NaN
# 3  4300020483      00400  5106550640            NaN            NaN
# 4  4300020483      00070  5106550895            NaN            NaN
#
#    IND_BORRADO_SP  CANT_UN_OC  CANT_FACTURA  CANTIDAD_BO VIA_TEXTO  \
# 0             NaN         1.0           1.0            0   Courier
# 1             NaN         1.0           1.0            0     Aéreo
# 2             NaN         1.0           1.0            0   Courier
# 3             NaN         1.0           1.0            0   Courier
# 4             NaN         1.0           1.0            0   Courier
#
#   FE_CONFIRMACION      FE_ATA
# 0      2023-01-05  2023-01-20
# 1      2023-01-19  2023-02-18
# 2             NaN  2023-05-01
# 3             NaN  2023-06-10
# ...
